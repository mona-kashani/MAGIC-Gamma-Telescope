# %%
# %cd /content/drive/My Drive/projects
# Out:
# /content/drive/My Drive/projects

# %% [markdown]
# #download data

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

# %% [markdown]
# #load data

# %%
import pandas as pd

# %%
names=[ 'fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 
       'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class']

# %%
data = pd.read_csv('magic04.data', names=names)
data
# Out:
#         fLength    fWidth   fSize   fConc  ...  fM3Trans   fAlpha     fDist  class
# 0       28.7967   16.0021  2.6449  0.3918  ...   -8.2027  40.0920   81.8828      g
# 1       31.6036   11.7235  2.5185  0.5303  ...   -9.9574   6.3609  205.2610      g
# 2      162.0520  136.0310  4.0612  0.0374  ...  -45.2160  76.9600  256.7880      g
# 3       23.8172    9.5728  2.3385  0.6147  ...   -7.1513  10.4490  116.7370      g
# 4       75.1362   30.9205  3.1611  0.3168  ...   21.8393   4.6480  356.4620      g
# ...         ...       ...     ...     ...  ...       ...      ...       ...    ...
# 19015   21.3846   10.9170  2.6161  0.5857  ...    2.8766   2.4229  106.8258      h
# 19016   28.9452    6.7020  2.2672  0.5351  ...   -2.9632  86.7975  247.4560      h
# 19017   75.4455   47.5305  3.4483  0.1417  ...   -9.4662  30.2987  256.5166      h
# 19018  120.5135   76.9018  3.9939  0.0944  ...  -63.8389  84.6874  408.3166      h
# ...

# %% [markdown]
# #data statistics

# %%
data.describe(include="all")
# Out:
#              fLength        fWidth  ...         fDist  class
# count   19020.000000  19020.000000  ...  19020.000000  19020
# unique           NaN           NaN  ...           NaN      2
# top              NaN           NaN  ...           NaN      g
# freq             NaN           NaN  ...           NaN  12332
# mean       53.250154     22.180966  ...    193.818026    NaN
# std        42.364855     18.346056  ...     74.731787    NaN
# min         4.283500      0.000000  ...      1.282600    NaN
# 25%        24.336000     11.863800  ...    142.492250    NaN
# 50%        37.147700     17.139900  ...    191.851450    NaN
# 75%        70.122175     24.739475  ...    240.563825    NaN
# max       334.177000    256.382000  ...    495.561000    NaN
#
# [11 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# fLength     0
# fWidth      0
# fSize       0
# fConc       0
# fConc1      0
# fAsym       0
# fM3Long     0
# fM3Trans    0
# fAlpha      0
# fDist       0
# class       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   19020 non-null  float64
#  1   fWidth    19020 non-null  float64
#  2   fSize     19020 non-null  float64
#  3   fConc     19020 non-null  float64
#  4   fConc1    19020 non-null  float64
#  5   fAsym     19020 non-null  float64
#  6   fM3Long   19020 non-null  float64
#  7   fM3Trans  19020 non-null  float64
#  8   fAlpha    19020 non-null  float64
#  9   fDist     19020 non-null  float64
#  10  class     19020 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.6+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.figure(figsize=(7,7))
sns.countplot(data['class'])
plt.show()

# %%
data['class'] = [0 if i=='h' else 1 for i in data['class']]

# %%
plt.figure(figsize=(17,17))
sns.pairplot(data=data, hue='class', plot_kws={'alpha': 0.1})
plt.show()

# %%
plt.figure(1,figsize=(15,5))

# plt.subplots_adjust(hspace=0.4,wspace=0.7)
names=[ 'fLength', 'fWidth','fSize' ,'fConc' ,'fConc1','fAsym' ,'fM3Long','fM3Trans' ,'fAlpha' ,'fDist','class']
plt.subplot(2, 5, 1)
plt.hist(x = 'fLength', data = data, rwidth=0.85, color='blue')
plt.title('fLength')
plt.xlabel('fLength')
plt.ylabel('count')

plt.subplot(2, 5, 2)
plt.hist(x = 'fWidth', data = data, rwidth=0.85, color='red')
plt.title('fWidth')
plt.xlabel('fWidth')
plt.ylabel('count')

plt.subplot(2, 5, 3)
plt.hist(x = 'fSize', data = data, rwidth=0.85, color='green')
plt.title('fSize')
plt.xlabel('fSize')
plt.ylabel('count')

plt.subplot(2, 5, 4)
plt.hist(x = 'fConc', data = data, rwidth=0.85, color='purple')
plt.title('fConc')
plt.xlabel('fConc')
plt.ylabel('count')

plt.subplot(2, 5, 5)
plt.hist(x = 'fConc1', data = data, rwidth=0.85, color='pink')
plt.title('fConc1')
plt.xlabel('fConc1')
plt.ylabel('count')

plt.subplot(2, 5, 6)
plt.hist(x = 'fAsym', data = data, rwidth=0.85, color='orange')
plt.title('fAsym')
plt.xlabel('fAsym')
plt.ylabel('count')

plt.subplot(2, 5, 7)
plt.hist(x = 'fM3Long', data = data, rwidth=0.85, color='gray')
plt.title('fM3Long')
plt.xlabel('fM3Long')
plt.ylabel('count')

plt.subplot(2, 5, 8)
plt.hist(x = 'fM3Trans', data = data, rwidth=0.85, color='yellow')
plt.title('fM3Trans')
plt.xlabel('fM3Trans')
plt.ylabel('count')

plt.subplot(2, 5, 9)
plt.hist(x = 'fAlpha', data = data, rwidth=0.85, color='cyan')
plt.title('fAlpha')
plt.xlabel('fAlpha')
plt.ylabel('count')

plt.subplot(2, 5, 10)
plt.hist(x = 'fDist', data = data, rwidth=0.85, color='black')
plt.title('fDist')
plt.xlabel('fDist')
plt.ylabel('count')

plt.tight_layout(pad=3.0)

# %%
C=data.corr()
plt.figure(figsize =(10,8))
sns.heatmap(C, annot=True, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# #data normalization

# %%
from sklearn import preprocessing

# %%
x_data = data.values[:, :-1]
y_data = data.values[:, -1]

# %%
minmax_scale = preprocessing.MinMaxScaler().fit(x_data)
x_minmax = minmax_scale.transform(x_data)

# %%
x_minmax.shape
# Out:
# (19020, 10)

# %%
y_data
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_minmax, y_data, test_size=0.2, random_state=42)

# %%
len(x_train), len(x_test)
# Out:
# (15216, 3804)

# %% [markdown]
# # feature engineering

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.005)
h = sel.fit_transform(x_train)

# %%
names=[ 'fLength', 'fWidth', 'fSize', 'fConc', 'fConc1',
       'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class']
for i, j in zip(names, sel.variances_):
    print(i, ' : ', j)
# Out:
# fLength  :  0.016435635869829282
# fWidth  :  0.005035673053144708
# fSize  :  0.0195239074430998
# fConc  :  0.043560627763426334
# fConc1  :  0.027097881047155725
# fAsym  :  0.0032722818657569585
# fM3Long  :  0.007983686917800837
# fM3Trans  :  0.0028860799955761447
# fAlpha  :  0.0840773998342451
# fDist  :  0.022887976812812596

# %% [markdown]
#     'fAsym' and 'fM3Trans' have variance lower than 0.005
#     we delete them and keep important features

# %%
ind = []
for i, j in enumerate(sel.variances_):
    if j>0.005 :
        ind.append(i)
ind
# Out:
# [0, 1, 2, 3, 4, 6, 8, 9]

# %%
x_train_var = x_train[:, ind]
x_test_var = x_test[:, ind]
x_train_var.shape, x_test_var.shape
# Out:
# ((15216, 8), (3804, 8))

# %% [markdown]
# #models implementation

# %%
from sklearn.metrics import *

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
clf1 = GaussianNB()
clf1.fit(x_train, y_train)
pred_test1 = clf1.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test1)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test1))

clf1 = GaussianNB()
clf1.fit(x_train_var, y_train)
pred_test1_2 = clf1.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test1_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test1_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
# Out:
# accuracy without feature engineering :  0.7268664563617245
# accuracy with feature engineering    :  0.7379074658254469

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf2 = DecisionTreeClassifier()
clf2.fit(x_train, y_train)
pred_test2 = clf2.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test2)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test2))

clf2 = DecisionTreeClassifier()
clf2.fit(x_train_var, y_train)
pred_test2_2 = clf2.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test2_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test2_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
# Out:
# accuracy without feature engineering :  0.8120399579390115
# accuracy with feature engineering    :  0.8146687697160884

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf3 = RandomForestClassifier()
clf3.fit(x_train, y_train)
pred_test3 = clf3.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test3)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test3))

clf3 = RandomForestClassifier()
clf3.fit(x_train_var, y_train)
pred_test3_2 = clf3.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test3_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test3_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
# Out:
# accuracy without feature engineering :  0.8817034700315457
# accuracy with feature engineering    :  0.8780231335436383

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
clf4 = LogisticRegression()
clf4.fit(x_train, y_train)
pred_test4 = clf4.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test4)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test4))

clf4 = LogisticRegression()
clf4.fit(x_train_var, y_train)
pred_test4_2 = clf4.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test4_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test4_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
# Out:
# accuracy without feature engineering :  0.7928496319663512
# accuracy with feature engineering    :  0.7923238696109358

# %% [markdown]
# ##KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
clf5 = KNeighborsClassifier()
clf5.fit(x_train, y_train)
pred_test5 = clf5.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test5)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test5))

clf5 = KNeighborsClassifier()
clf5.fit(x_train_var, y_train)
pred_test5_2 = clf5.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test5_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test5_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
# Out:
# accuracy without feature engineering :  0.8351735015772871
# accuracy with feature engineering    :  0.8362250262881178

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
clf6 = SVC()
clf6.fit(x_train, y_train)
pred_test6 = clf6.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test6)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test6))

clf6 = SVC()
clf6.fit(x_train_var, y_train)
pred_test6_2 = clf6.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test6_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test6_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
plt.show()
# Out:
# accuracy without feature engineering :  0.8585699263932702
# accuracy with feature engineering    :  0.8601472134595163

# %% [markdown]
# #comparison

# %%
acc, f1, precision, recall = [], [], [], []
acc_2, f1_2, precision_2, recall_2 = [], [], [], []

acc.append(accuracy_score(y_test, pred_test1))
acc.append(accuracy_score(y_test, pred_test2))
acc.append(accuracy_score(y_test, pred_test3))
acc.append(accuracy_score(y_test, pred_test4))
acc.append(accuracy_score(y_test, pred_test5))
acc.append(accuracy_score(y_test, pred_test6))

acc_2.append(accuracy_score(y_test, pred_test1_2))
acc_2.append(accuracy_score(y_test, pred_test2_2))
acc_2.append(accuracy_score(y_test, pred_test3_2))
acc_2.append(accuracy_score(y_test, pred_test4_2))
acc_2.append(accuracy_score(y_test, pred_test5_2))
acc_2.append(accuracy_score(y_test, pred_test6_2))

f1.append(f1_score(y_test, pred_test1))
f1.append(f1_score(y_test, pred_test2))
f1.append(f1_score(y_test, pred_test3))
f1.append(f1_score(y_test, pred_test4))
f1.append(f1_score(y_test, pred_test5))
f1.append(f1_score(y_test, pred_test6))

f1_2.append(f1_score(y_test, pred_test1_2))
f1_2.append(f1_score(y_test, pred_test2_2))
f1_2.append(f1_score(y_test, pred_test3_2))
f1_2.append(f1_score(y_test, pred_test4_2))
f1_2.append(f1_score(y_test, pred_test5_2))
f1_2.append(f1_score(y_test, pred_test6_2))

precision.append(precision_score(y_test, pred_test1))
precision.append(precision_score(y_test, pred_test2))
precision.append(precision_score(y_test, pred_test3))
precision.append(precision_score(y_test, pred_test4))
precision.append(precision_score(y_test, pred_test5))
precision.append(precision_score(y_test, pred_test6))

precision_2.append(precision_score(y_test, pred_test1_2))
precision_2.append(precision_score(y_test, pred_test2_2))
precision_2.append(precision_score(y_test, pred_test3_2))
precision_2.append(precision_score(y_test, pred_test4_2))
precision_2.append(precision_score(y_test, pred_test5_2))
precision_2.append(precision_score(y_test, pred_test6_2))

recall.append(recall_score(y_test, pred_test1))
recall.append(recall_score(y_test, pred_test2))
recall.append(recall_score(y_test, pred_test3))
recall.append(recall_score(y_test, pred_test4))
recall.append(recall_score(y_test, pred_test5))
recall.append(recall_score(y_test, pred_test6))

recall_2.append(recall_score(y_test, pred_test1_2))
recall_2.append(recall_score(y_test, pred_test2_2))
recall_2.append(recall_score(y_test, pred_test3_2))
recall_2.append(recall_score(y_test, pred_test4_2))
recall_2.append(recall_score(y_test, pred_test5_2))
recall_2.append(recall_score(y_test, pred_test6_2))

# %%
print('accuracy  : ', acc)
print('accuracy  : ', acc_2)
print()
print('f1_score  : ', f1)
print('f1_score  : ', f1_2)
print()
print('precision : ', precision)
print('precision : ', precision_2)
print()
print('recall    : ', recall)
print('recall    : ', recall_2)
# Out:
# accuracy  :  [0.7268664563617245, 0.8120399579390115, 0.8817034700315457, 0.7928496319663512, 0.8351735015772871, 0.8585699263932702]
# accuracy  :  [0.7379074658254469, 0.8146687697160884, 0.8780231335436383, 0.7923238696109358, 0.8362250262881178, 0.8601472134595163]
#
# f1_score  :  [0.8128939312083558, 0.854586129753915, 0.9113125739061885, 0.8486361890126777, 0.8793070259865255, 0.89717125382263]
# f1_score  :  [0.8189576902124568, 0.8563862293746181, 0.9085534095388255, 0.848310291858679, 0.8798920377867746, 0.8982791586998088]
#
# precision :  [0.72971225347559, 0.8551078551078551, 0.8844682478959449, 0.8044428259286235, 0.8351005484460695, 0.8466810966810967]
# precision :  [0.740072202166065, 0.8583095140873827, 0.8817903596021424, 0.8038573508005823, 0.8368170150348369, 0.848014440433213]
#
# recall    :  [0.917479674796748, 0.8540650406504066, 0.9398373983739837, 0.8979674796747967, 0.9284552845528455, 0.9540650406504065]
# ...

# %%
# NB ='GaussianNB'
# DT = 'DecisionTreeClassifier'
# RF = 'RandomForestClassifier'
# LR = 'LogisticRegression'
# KNN = 'KNeighborsClassifier'
# SVC = 'SVC'

fig = plt.figure(1,figsize=(15, 10))
fig.suptitle('models comparison', fontsize=20)
plt.subplot(2, 2, 1)
names = ['NB', 'DT', 'RF', 'LR', 'KNN', 'SVC']
plt.plot(names, acc, label='normal acc')
plt.plot(names, acc_2, label='FE acc')
plt.title('accuracy', fontsize=15)
plt.legend()

plt.subplot(2, 2, 2)
names = ['NB', 'DT', 'RF', 'LR', 'KNN', 'SVC']
plt.plot(names, f1, label='normal f1_score')
plt.plot(names, f1_2, label='FE f1_score')
plt.title("f1_score", fontsize=15)
plt.legend()

plt.subplot(2, 2, 3)
names = ['NB', 'DT', 'RF', 'LR', 'KNN', 'SVC']
plt.plot(names, precision, label='normal precision')
plt.plot(names, precision_2, label='FE precision')
plt.title("precision", fontsize=15)
plt.legend()

plt.subplot(2, 2, 4)
names = ['NB', 'DT', 'RF', 'LR', 'KNN', 'SVC']
plt.plot(names, recall, label='normal recall')
plt.plot(names, recall_2, label='FE recall')
plt.title("recall", fontsize=15)
plt.legend()

plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# # ensemble learning

# %%
from sklearn.ensemble import VotingClassifier

clf1 = GaussianNB()
clf2 = DecisionTreeClassifier()
clf3 = RandomForestClassifier()
clf4 = LogisticRegression()
clf5 = KNeighborsClassifier()
clf6 = SVC()

eclf = VotingClassifier(estimators=[('nb', clf1), ('dt', clf2), ('rf', clf3),
                                    ('lr', clf4), ('knn', clf5), ('svm', clf6)])
eclf.fit(x_train, y_train)
pred_test_vc = eclf.predict(x_test)
conf1 = confusion_matrix(y_test, pred_test_vc)
print("accuracy without feature engineering : ", accuracy_score(y_test, pred_test_vc))

clf1 = GaussianNB()
clf2 = DecisionTreeClassifier()
clf3 = RandomForestClassifier()
clf4 = LogisticRegression()
clf5 = KNeighborsClassifier()
clf6 = SVC()

eclf = VotingClassifier(estimators=[('nb', clf1), ('dt', clf2), ('rf', clf3),
                                    ('lr', clf4), ('knn', clf5), ('svm', clf6)])
eclf.fit(x_train_var, y_train)
pred_test_vc_2 = eclf.predict(x_test_var)
conf2 = confusion_matrix(y_test, pred_test_vc_2)
print("accuracy with feature engineering    : ", accuracy_score(y_test, pred_test_vc_2))

fig = plt.figure(1,figsize=(15,6))
fig.suptitle('confusion matrix', fontsize=20)
plt.subplot(1, 2, 1)
sns.heatmap(conf1, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('without feature engineering')

plt.subplot(1, 2, 2)
sns.heatmap(conf2, annot=True, fmt='g', cmap=plt.cm.Blues)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('with feature engineering')

plt.tight_layout(pad=3.0)
plt.show()
# Out:
# accuracy without feature engineering :  0.8633017875920084
# accuracy with feature engineering    :  0.8648790746582544

# %% [markdown]
# #visualization

# %%
sns.scatterplot(x=x_test[:, 0], y=x_test[:, 1], hue=y_test)
plt.show()

# %%
from sklearn.decomposition import PCA
pc=PCA(n_components=2)
data2=pc.fit_transform(x_test)

# %%
data2.shape
# Out:
# (3804, 2)

# %%
len(y_test), len(data2)
# Out:
# (3804, 3804)

# %%
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=y_test)
plt.show()

# %%
plt.figure(1,figsize=(15,7))

plt.subplot(2, 3, 1)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test1_2)
plt.title("GaussianNB")

plt.subplot(2, 3, 2)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test2_2)
plt.title("DecisionTreeClassifier")

plt.subplot(2, 3, 3)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test3_2)
plt.title("RandomForestClassifier")

plt.subplot(2, 3, 4)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test4_2)
plt.title("LogisticRegression")

plt.subplot(2, 3, 5)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test5_2)
plt.title("KNeighborsClassifier")

plt.subplot(2, 3, 6)
sns.scatterplot(x=data2[:, 0], y=data2[:, 1], hue=pred_test6_2)
plt.title("SVC")

plt.tight_layout(pad=3.0)
plt.show()
